# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dataset.csv')

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.replace(0,np.nan,inplace=True)

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40               NaN
# 1     C10002  3202.467416           0.909091        NaN               NaN
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12               NaN
# 8946  C19187    19.183215           1.000000     300.00               NaN
# 8947  C19188    23.398673           0.833333     144.40               NaN
# 8948  C19189    13.457564           0.833333        NaN               NaN
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                    float64
# PURCHASES_TRX                       float64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
df.dropna(thresh=2200,axis=1,inplace=True)

# %%
df = df.drop('CUST_ID', axis=1)

# %%
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40               NaN
# 1     3202.467416           0.909091        NaN               NaN
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12               NaN
# 8946    19.183215           1.000000     300.00               NaN
# 8947    23.398673           0.833333     144.40               NaN
# 8948    13.457564           0.833333        NaN               NaN
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40           NaN             0.166667
# ...

# %%
column_means = df.mean(numeric_only=True)
df = df.fillna(column_means)

# %%
df
# Out:
#           BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182    95.400000       1140.773337
# 1     3202.467416           0.909091  1300.127897       1140.773337
# 2     2495.148862           1.000000   773.170000        773.170000
# 3     1666.670542           0.636364  1499.000000       1499.000000
# 4      817.714335           1.000000    16.000000         16.000000
# ...           ...                ...          ...               ...
# 8945    28.493517           1.000000   291.120000       1140.773337
# 8946    19.183215           1.000000   300.000000       1140.773337
# 8947    23.398673           0.833333   144.400000       1140.773337
# 8948    13.457564           0.833333  1300.127897       1140.773337
# 8949   372.708075           0.666667  1093.250000       1093.250000
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                  95.400000   2027.046843             0.166667
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1578.585085           0.885183   1300.127897       1140.773337
# std     2076.221895           0.221769   2065.744479       1558.953777
# min        0.000199           0.090909      0.010000          0.010000
# 25%      138.552580           0.888889    327.477500        500.000000
# 50%      908.814551           1.000000   1009.000000       1140.773337
# 75%     2054.140036           1.000000   1300.127897       1140.773337
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               730.841363   2027.046843             0.635390
# std                828.470946   1836.287758             0.299951
# min                  1.950000     14.222216             0.083333
# ...

# %%
df.skew(numeric_only=True)
# Out:
# BALANCE                              2.395229
# BALANCE_FREQUENCY                   -2.020031
# PURCHASES                            8.604402
# ONEOFF_PURCHASES                    11.073580
# INSTALLMENTS_PURCHASES               8.356515
# CASH_ADVANCE                         5.971966
# PURCHASES_FREQUENCY                 -0.396472
# ONEOFF_PURCHASES_FREQUENCY           1.095098
# PURCHASES_INSTALLMENTS_FREQUENCY    -0.481177
# CASH_ADVANCE_FREQUENCY               1.899775
# CASH_ADVANCE_TRX                     6.911187
# PURCHASES_TRX                        4.952497
# CREDIT_LIMIT                         1.522549
# PAYMENTS                             5.952324
# MINIMUM_PAYMENTS                    13.867357
# PRC_FULL_PAYMENT                     0.816751
# TENURE                              -2.943017
# dtype: float64

# %%
df.plot(subplots=True,title="Skewness information",
        layout=(9,2), legend=True,x_compat=True,
        figsize=(20,30))
plt.show()

# %%
df['BALANCE'].plot.kde(bw_method=1)
plt.xlabel('balance')
# Out:
# Text(0.5, 0, 'balance')

# %%
df['CREDIT_LIMIT'].plot.kde(bw_method=1)
plt.xlabel('credit_limit')
# Out:
# Text(0.5, 0, 'credit_limit')

# %%
df['PURCHASES'].plot.kde(bw_method=1)
plt.xlabel('purchases')
# Out:
# Text(0.5, 0, 'purchases')

# %%
       for column in df.columns:
        try:
            df[column] = np.log(df[column])
        
        except (ValueError, AttributeError):
            pass

# %%
df.skew(numeric_only=True)
# Out:
# BALANCE                            -1.052075
# BALANCE_FREQUENCY                  -3.006902
# PURCHASES                          -0.979628
# ONEOFF_PURCHASES                   -2.038579
# INSTALLMENTS_PURCHASES             -1.034482
# CASH_ADVANCE                       -1.616801
# PURCHASES_FREQUENCY                -1.379837
# ONEOFF_PURCHASES_FREQUENCY         -0.725333
# PURCHASES_INSTALLMENTS_FREQUENCY   -2.005664
# CASH_ADVANCE_FREQUENCY             -0.568218
# CASH_ADVANCE_TRX                   -0.688840
# PURCHASES_TRX                      -0.555139
# CREDIT_LIMIT                       -0.102541
# PAYMENTS                           -0.209229
# MINIMUM_PAYMENTS                   -0.054429
# PRC_FULL_PAYMENT                   -1.428354
# TENURE                             -3.199319
# dtype: float64

# %%
df.plot(subplots=True, title="Skewness information",
        layout=(9,2), legend=True,x_compat=True,
        figsize=(20,30))
plt.show()

# %%
df['BALANCE'].plot.kde(bw_method=1)
plt.xlabel('balance_improved')
# Out:
# Text(0.5, 0, 'balance_improved')

# %%
df['CREDIT_LIMIT'].plot.kde(bw_method=1)
plt.xlabel('credit_limit_improved')
# Out:
# Text(0.5, 0, 'credit_limit_improved')

# %%
df['PURCHASES'].plot.kde(bw_method=1)
plt.xlabel('purchases_improved')
# Out:
# Text(0.5, 0, 'purchases_improved')

# %%
df.head(8)
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  3.711148          -0.200670   4.558079          7.039462
# 1  8.071677          -0.095310   7.170218          7.039462
# 2  7.822104           0.000000   6.650499          6.650499
# 3  7.418583          -0.451985   7.312553          7.312553
# 4  6.706513           0.000000   2.772589          2.772589
# 5  7.500988           0.000000   7.195397          7.039462
# 6  6.441362           0.000000   8.866583          8.764464
# 7  7.508597           0.000000   6.078101          7.039462
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                4.558079      7.614335            -1.791757
# 1                6.594196      8.770741            -0.453517
# 2                6.594196      7.614335             0.000000
# 3                6.594196      5.326847            -2.484911
# 4                6.594196      7.614335            -2.484911
# ...

# %%
df.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.602113   0.347743
# BALANCE_FREQUENCY                 0.602113           1.000000   0.232143
# PURCHASES                         0.347743           0.232143   1.000000
# ONEOFF_PURCHASES                  0.111232           0.080884   0.600371
# INSTALLMENTS_PURCHASES            0.230583           0.121982   0.549819
# CASH_ADVANCE                      0.019339          -0.035455  -0.028078
# PURCHASES_FREQUENCY               0.103537           0.315191   0.592078
# ONEOFF_PURCHASES_FREQUENCY        0.063745           0.150847   0.426537
# PURCHASES_INSTALLMENTS_FREQUENCY  0.090718           0.196609   0.290934
# CASH_ADVANCE_FREQUENCY            0.047748           0.078397  -0.053576
# CASH_ADVANCE_TRX                  0.008189           0.045500  -0.063863
# PURCHASES_TRX                     0.254819           0.297219   0.761538
# ...

# %%
correlation = df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(correlation,vmax=1,square=True,annot=True,cmap='Blues',linecolor='black',linewidths=2)

plt.title('Correlation between different features')
# Out:
# Text(0.5, 1.0, 'Correlation between different features')

# %% [markdown]
# ***PCA***

# %%
df.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  3.711148          -0.200670   4.558079          7.039462
# 1  8.071677          -0.095310   7.170218          7.039462
# 2  7.822104           0.000000   6.650499          6.650499
# 3  7.418583          -0.451985   7.312553          7.312553
# 4  6.706513           0.000000   2.772589          2.772589
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                4.558079      7.614335            -1.791757
# 1                6.594196      8.770741            -0.453517
# 2                6.594196      7.614335             0.000000
# 3                6.594196      5.326847            -2.484911
# 4                6.594196      7.614335            -2.484911
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.942008                         -2.484911
# 1                   -0.942008                         -0.434161
# ...

# %%
X=df

# %%
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)

# %%
X
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     3.711148          -0.200670   4.558079          7.039462
# 1     8.071677          -0.095310   7.170218          7.039462
# 2     7.822104           0.000000   6.650499          6.650499
# 3     7.418583          -0.451985   7.312553          7.312553
# 4     6.706513           0.000000   2.772589          2.772589
# ...        ...                ...        ...               ...
# 8945  3.349677           0.000000   5.673736          7.039462
# 8946  2.954036           0.000000   5.703782          7.039462
# 8947  3.152679          -0.182322   4.972587          7.039462
# 8948  2.599541          -0.182322   7.170218          7.039462
# 8949  5.920795          -0.405465   6.996910          6.996910
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   4.558079      7.614335            -1.791757
# 1                   6.594196      8.770741            -0.453517
# ...

# %%
X.plot(subplots=True, grid=False, title="After Standardization",
        layout=(9,2), legend=True,x_compat=True,
        figsize=(20,30))
plt.show()

# %%
from sklearn.decomposition import PCA
pca = PCA().fit(X_std)
arr=np.cumsum(pca.explained_variance_ratio_)
plt.plot(arr)
plt.xlim(0,18,1)
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
X1=[0,2.8]
Y1=[0.6,0.6]
X2=[0,4]
Y2=[0.7,0.7]
X3=[0,3]
Y3=[0.63,0.63]
X4=[0,6]
Y4=[0.82,0.82]
X5=[6,6]
Y5=[0,0.82]
plt.plot(X1,Y1,X2,Y2,X3,Y3,X4,Y4,X5,Y5)
plt.show()

# %%
from sklearn.decomposition import PCA 
sklearn_pca = PCA(n_components=6)
Y_sklearn = sklearn_pca.fit_transform(X_std)

# %%
Y_sklearn.shape
# Out:
# (8950, 6)

# %%
Y_sklearn
# Out:
# array([[ 3.91931827,  0.40375382,  1.29319836, -2.96221606, -0.52381194,
#          0.16223435],
#        [-1.87682663,  1.13367103, -0.80553192, -0.36936439,  0.81342506,
#          0.62436185],
#        [-1.52940124,  0.52511169,  0.26776633, -0.41618547, -0.3741361 ,
#         -0.29722277],
#        ...,
#        [ 2.39632857, -0.92482875,  3.05733962,  0.60650635, -2.87340854,
#         -0.06412886],
#        [ 1.4505805 , -4.86042031,  1.91086337,  1.28939475, -2.57750248,
#         -0.21507758],
#        [ 0.52043093, -3.14167517,  2.0207839 ,  0.92386494, -2.5547859 ,
#         -1.56241641]])

# %%
arr1=pd.DataFrame(Y_sklearn)
arr1
# Out:
#              0         1         2         3         4         5
# 0     3.919318  0.403754  1.293198 -2.962216 -0.523812  0.162234
# 1    -1.876827  1.133671 -0.805532 -0.369364  0.813425  0.624362
# 2    -1.529401  0.525112  0.267766 -0.416185 -0.374136 -0.297223
# 3     1.442424 -1.858812 -3.668803 -0.302747  2.197270 -1.408440
# 4     4.596848  1.506849 -2.528895  1.921753 -0.716037  0.177213
# ...        ...       ...       ...       ...       ...       ...
# 8945  1.389224 -0.937116  3.038249  1.317805 -2.476728 -0.969892
# 8946  0.995083 -0.546772  2.115155  0.967758 -2.884047 -1.197043
# 8947  2.396329 -0.924829  3.057340  0.606506 -2.873409 -0.064129
# 8948  1.450580 -4.860420  1.910863  1.289395 -2.577502 -0.215078
# 8949  0.520431 -3.141675  2.020784  0.923865 -2.554786 -1.562416
#
# [8950 rows x 6 columns]

# %%
from sklearn.cluster import KMeans

# %%
Sum_of_squared_distances = []
K = range(1,20)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(Y_sklearn)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
XA=[0,5]
YA=[60000,60000]
XB=[5,5]
YB=[0,60000]
plt.plot(XA,YA,XB,YB)
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(Y_sklearn)
# Out:
# KMeans(n_clusters=5)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[ 0.27336388 -0.20276245  1.12347646  0.47554415 -0.5526864   0.08198927]
#  [ 2.87610926  0.86011981 -1.4756112   1.11101508  0.38730212 -0.18845418]
#  [ 2.49770657  0.67447235  0.62386314 -2.33578504  0.10346521  0.00930085]
#  [-1.9014059   0.9198934  -0.04107637  0.0391134   0.18554843  0.00779209]
#  [-0.56243352 -2.54212575 -1.00532355 -0.32872591  0.19187565 -0.00823031]]

# %%
arr=kmeans.labels_
group=pd.DataFrame(arr,columns=['clust'])
group
# Out:
#       clust
# 0         2
# 1         3
# 2         3
# 3         4
# 4         1
# ...     ...
# 8945      0
# 8946      0
# 8947      0
# 8948      4
# 8949      0
#
# [8950 rows x 1 columns]

# %%
group.describe()
# Out:
#              clust
# count  8950.000000
# mean      1.971285
# std       1.492171
# min       0.000000
# 25%       0.000000
# 50%       2.000000
# 75%       3.000000
# max       4.000000

# %%
arr1
# Out:
#              0         1         2         3         4         5
# 0     3.919318  0.403754  1.293198 -2.962216 -0.523812  0.162234
# 1    -1.876827  1.133671 -0.805532 -0.369364  0.813425  0.624362
# 2    -1.529401  0.525112  0.267766 -0.416185 -0.374136 -0.297223
# 3     1.442424 -1.858812 -3.668803 -0.302747  2.197270 -1.408440
# 4     4.596848  1.506849 -2.528895  1.921753 -0.716037  0.177213
# ...        ...       ...       ...       ...       ...       ...
# 8945  1.389224 -0.937116  3.038249  1.317805 -2.476728 -0.969892
# 8946  0.995083 -0.546772  2.115155  0.967758 -2.884047 -1.197043
# 8947  2.396329 -0.924829  3.057340  0.606506 -2.873409 -0.064129
# 8948  1.450580 -4.860420  1.910863  1.289395 -2.577502 -0.215078
# 8949  0.520431 -3.141675  2.020784  0.923865 -2.554786 -1.562416
#
# [8950 rows x 6 columns]

# %%
label = pd.concat((group,arr1),axis=1)
label.rename(columns = {0:'PC_1'}, inplace = True)
label.rename(columns = {1:'PC_2'}, inplace = True)
label.rename(columns = {2:'PC_3'}, inplace = True)
label.rename(columns = {3:'PC_4'}, inplace = True)
label.rename(columns = {4:'PC_5'}, inplace = True)
label.rename(columns = {5:'PC_6'}, inplace = True)

# %%
label
# Out:
#       clust      PC_1      PC_2      PC_3      PC_4      PC_5      PC_6
# 0         2  3.919318  0.403754  1.293198 -2.962216 -0.523812  0.162234
# 1         3 -1.876827  1.133671 -0.805532 -0.369364  0.813425  0.624362
# 2         3 -1.529401  0.525112  0.267766 -0.416185 -0.374136 -0.297223
# 3         4  1.442424 -1.858812 -3.668803 -0.302747  2.197270 -1.408440
# 4         1  4.596848  1.506849 -2.528895  1.921753 -0.716037  0.177213
# ...     ...       ...       ...       ...       ...       ...       ...
# 8945      0  1.389224 -0.937116  3.038249  1.317805 -2.476728 -0.969892
# 8946      0  0.995083 -0.546772  2.115155  0.967758 -2.884047 -1.197043
# 8947      0  2.396329 -0.924829  3.057340  0.606506 -2.873409 -0.064129
# 8948      4  1.450580 -4.860420  1.910863  1.289395 -2.577502 -0.215078
# 8949      0  0.520431 -3.141675  2.020784  0.923865 -2.554786 -1.562416
#
# [8950 rows x 7 columns]

# %%
sns.scatterplot(x='PC_1',y='PC_2',data=label,hue='clust')
# Out:
# <AxesSubplot:xlabel='PC_1', ylabel='PC_2'>
